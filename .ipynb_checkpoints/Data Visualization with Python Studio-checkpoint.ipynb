# %% [markdown]
# # Data Visualization with Python Studio
#
# At this point, you should already have connected with the rest of your group to divide up who is going to do what. Use this notebook to create your visualizations.
#
# Below we set up the dataframe with the Goodreads dataset for you. If you run this cell, you may get an error that some lines were skipped. Do not worry about that! For this studio, we want to focus on creating an effective

# %%
# Here is the setup of the dataframe. Feel free to use .info() or .head() to get a better understanding of what is inside the dataframe!

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv("books.csv", error_bad_lines=False)

years = []

for y in df['publication_date']:
    date = y.split("/")
    years.append(date[2])

df["year"] = years
df.head(30)
# Out:
# C:\Users\kelle\AppData\Local\Temp\ipykernel_31052\715409528.py:9: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("books.csv", error_bad_lines=False)
# Skipping line 3350: expected 12 fields, saw 13
# Skipping line 4704: expected 12 fields, saw 13
# Skipping line 5879: expected 12 fields, saw 13
# Skipping line 8981: expected 12 fields, saw 13
#     bookID                                              title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5        9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6       10       Harry Potter Collection (Harry Potter  #1-6)
# 7       12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8       13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9       14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10      16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 11      18  The Ultimate Hitchhiker's Guide (Hitchhiker's ...
# 12      21               A Short History of Nearly Everything
# 13      22                        Bill Bryson's African Diary
# 14      23  Bryson's Dictionary of Troublesome Words: A Wr...
# 15      24                             In a Sunburned Country
# 16      25  I'm a Stranger Here Myself: Notes on Returning...
# 17      26  The Lost Continent: Travels in Small Town America
# 18      27          Neither Here nor There: Travels in Europe
# 19      28                          Notes from a Small Island
# 20      29  The Mother Tongue: English and How It Got That...
# 21      30  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 22      31  The Lord of the Rings (The Lord of the Rings  ...
# 23      34  The Fellowship of the Ring (The Lord of the Ri...
# 24      35  The Lord of the Rings (The Lord of the Rings  ...
# 25      36         The Lord of the Rings: Weapons and Warfare
# 26      37   The Lord of the Rings: Complete Visual Companion
# 27      45  Agile Web Development with Rails: A Pragmatic ...
# 28      50                         Hatchet (Brian's Saga  #1)
# 29      51  Hatchet: A Guide for Using "Hatchet" in the Cl...
#
#                                               authors  average_rating  \
# 0                          J.K. Rowling/Mary GrandPré            4.57
# 1                          J.K. Rowling/Mary GrandPré            4.49
# 2                                        J.K. Rowling            4.42
# 3                          J.K. Rowling/Mary GrandPré            4.56
# 4                          J.K. Rowling/Mary GrandPré            4.78
# 5                              W. Frederick Zimmerman            3.74
# 6                                        J.K. Rowling            4.73
# 7                                       Douglas Adams            4.38
# 8                                       Douglas Adams            4.38
# 9                                       Douglas Adams            4.22
# 10                          Douglas Adams/Stephen Fry            4.22
# 11                                      Douglas Adams            4.38
# 16                2211        6/28/2000
# 17                2257        8/28/1990
# 18                2238        3/28/1993
# 19                3301        5/28/1997
# 20                2085        9/28/1991
# 21                1550        9/25/2012
# 22                  91       10/21/2004
# 23               13670         9/5/2003
# 24                 140        10/1/2002
# 25                  46        11/5/2003
# 26                   6       11/15/2004
# 27                  59        7/28/2005
# 28               12017         4/1/2000
# 29                   2        8/28/1994
#
#                                             publisher  year
# 0                                     Scholastic Inc.  2006
# 1                                     Scholastic Inc.  2004
# 2                                          Scholastic  2003
# 3                                     Scholastic Inc.  2004
# 4                                          Scholastic  2004
# 5                                        Nimble Books  2005
# 6                                          Scholastic  2005
# 7                                      Gramercy Books  2005
# 8                                       Del Rey Books  2002
# 9                                               Crown  2004
# 10                                 Random House Audio  2005
# 11                                        Wings Books  1996
# 12                                     Broadway Books  2004
# 13                                     Broadway Books  2002
# 14                                     Broadway Books  2004
# 15                                     Broadway Books  2001
# 16                                     Broadway Books  2000
# 17                          William Morrow Paperbacks  1990
# 18                          William Morrow Paperbacks  1993
# 19                          William Morrow Paperbacks  1997
# 20                          William Morrow Paperbacks  1991
# 21                                   Ballantine Books  2012
# 22                          Houghton Mifflin Harcourt  2004
# 23                          Houghton Mifflin Harcourt  2003
# 24                          Houghton Mifflin Harcourt  2002
# 25                          Houghton Mifflin Harcourt  2003
# 26                          Houghton Mifflin Harcourt  2004
# 27                                Pragmatic Bookshelf  2005
# 28  Atheneum Books for Young Readers: Richard Jack...  2000
# 29                          Teacher Created Resources  1994

# %% [markdown]
# With your dataframe set up, time to start creating visualizations!

# %%
# Use your Python skills to create a visualization here.
Year = df.groupby('year').sum()

xpos = np.arange(len(df))

plt.xticks(xpos,Year)
plt.ylabel('Number of Books')
plt.xlabel('Year')
plt.title('Number of Books per Year')
plt.bar(xpos, Year, label="Year")
plt.legend()
# Out:
# C:\Users\kelle\AppData\Local\Temp\ipykernel_31052\85777450.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Year = df.groupby('year').sum()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 6
#       2 Year = df.groupby('year').sum()
#       4 xpos = np.arange(len(df))
# ----> 6 plt.xticks(xpos,Year)
#       7 plt.ylabel('Number of Books')
#       8 plt.xlabel('Year')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1866, in xticks(ticks, labels, minor, **kwargs)
#    1864         l._internal_update(kwargs)
#    1865 else:
# -> 1866     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1868 return locs, labels
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1973, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1969 if isinstance(locator, mticker.FixedLocator):
#    1970     # Passing [] as a list of labels is often used as a way to
#    1971     # remove all tick labels, so only error for > 0 labels
#    1972     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1973         raise ValueError(
#    1974             "The number of FixedLocator locations"
#    1975             f" ({len(locator.locs)}), usually from a call to"
#    1976             " set_ticks, does not match"
#    1977             f" the number of labels ({len(labels)}).")
#    1978     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    1979     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (11123), usually from a call to set_ticks, does not match the number of labels (6).

# %%
# Use your Python skills to create a visualization here.
